# %%
import json
import pandas as pd
import numpy as np
import pandas
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from collections import Counter

# %%
from pprint import pprint

with open('Forbes 2019.json') as f:
    data = json.load(f)

pprint(data)
# Out:
# [{'age': 59,
#   'country': 'India',
#   'gender': 'M',
#   'imageUri': 'ajay-kalsi',
#   'industry': 'Energy',
#   'lastName': 'Kalsi',
#   'name': 'Ajay Kalsi',
#   'realTimePosition': 2174,
#   'realTimeRank': 2174,
#   'realTimeWorth': 1002.865,
#   'source': 'oil & gas',
#   'squareImage': 'http://specials-images.forbesimg.com/imageserve/f1c1ff9778a03817c0d1e06535d75074/416x416.jpg?background=000000&cropX1=0&cropX2=372&cropY1=28&cropY2=400',
#   'timestamp': 1578626401457,
#   'uri': 'ajay-kalsi',
#   'worthChange': 0.0},
#  {'age': 81,
#   'country': 'Canada',
#   'gender': 'M',
#   'imageUri': 'aldo-bensadoun',
#   'industry': 'Fashion & Retail',
#   'lastName': 'Bensadoun',
#   'name': 'Aldo Bensadoun',
#   'realTimePosition': 2165,
#   'realTimeRank': 2165,
#   'realTimeWorth': 1017.859,
#   'source': 'shoes',
#   'timestamp': 1578626401457,
#   'uri': 'aldo-bensadoun',
#   'worthChange': 0.0},
#  {'age': 44,
#   'country': 'Germany',
#   'gender': 'M',
# ...

# %%
# convert the list - data into a dataframe
df = pd.DataFrame(data)

# %%
df.head(5)
# Out:
#     age        country gender government headquarters          imageUri  \
# 0  59.0          India      M        NaN          NaN        ajay-kalsi
# 1  81.0         Canada      M        NaN          NaN    aldo-bensadoun
# 2  44.0        Germany      M        NaN          NaN  alexander-samwer
# 3  77.0  United States      M        NaN           PA            no-pic
# 4  65.0          India      M        NaN          NaN     analjit-singh
#
#                   industry   lastName  managementAssets              name  \
# 0                   Energy      Kalsi               NaN        Ajay Kalsi
# 1         Fashion & Retail  Bensadoun               NaN    Aldo Bensadoun
# 2               Technology     Samwer               NaN  Alexander Samwer
# 3  Finance and Investments       West               NaN    Alfred West Jr
# 4               Healthcare      Singh               NaN     Analjit Singh
#
#       ...      realTimeWorth  salary            source  \
# ...

# %%
data
# Out:
# [{'age': 59,
#   'country': 'India',
#   'gender': 'M',
#   'imageUri': 'ajay-kalsi',
#   'industry': 'Energy',
#   'lastName': 'Kalsi',
#   'name': 'Ajay Kalsi',
#   'realTimePosition': 2174,
#   'realTimeRank': 2174,
#   'realTimeWorth': 1002.865,
#   'source': 'oil & gas',
#   'squareImage': 'http://specials-images.forbesimg.com/imageserve/f1c1ff9778a03817c0d1e06535d75074/416x416.jpg?background=000000&cropX1=0&cropX2=372&cropY1=28&cropY2=400',
#   'timestamp': 1578626401457,
#   'uri': 'ajay-kalsi',
#   'worthChange': 0.0},
#  {'age': 81,
#   'country': 'Canada',
#   'gender': 'M',
#   'imageUri': 'aldo-bensadoun',
#   'industry': 'Fashion & Retail',
#   'lastName': 'Bensadoun',
#   'name': 'Aldo Bensadoun',
#   'realTimePosition': 2165,
#   'realTimeRank': 2165,
#   'realTimeWorth': 1017.859,
#   'source': 'shoes',
#   'timestamp': 1578626401457,
#   'uri': 'aldo-bensadoun',
#   'worthChange': 0.0},
#  {'age': 44,
#   'country': 'Germany',
#   'gender': 'M',
# ...
